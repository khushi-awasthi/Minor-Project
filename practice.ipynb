# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('datasets/Web_Scrapped_websites.csv',encoding='latin-1' )
df
# Out:
#       Country_Rank                    Website Trustworthiness  \
# 0                1          www.google.com.af       Excellent
# 1                2             www.google.com       Excellent
# 2                3            www.youtube.com       Excellent
# 3                4           www.facebook.com       Excellent
# 4                5              www.yahoo.com       Excellent
# ...            ...                        ...             ...
# 9535            46  www.newsdzezimbabwe.co.uk         Unknown
# 9536            47       www.nehandaradio.com         Unknown
# 9537            48         www.mysagagame.com       Very poor
# 9538            49                 www.ntd.tv  Unsatisfactory
# 9539            50  www.emailaccessonline.com            Poor
#
#      Avg_Daily_Visitors Child_Safety Avg_Daily_Pageviews         Privacy  \
# 0                   NaN    Excellent                 NaN       Excellent
# 1           515 007 350    Excellent       4 192 159 833       Excellent
# 2           506 457 282    Excellent       2 679 159 025       Excellent
# 3           270 071 255         Good       1 082 985 733       Excellent
# 4            99 572 035    Excellent         383 352 336       Excellent
# ...                 ...          ...                 ...             ...
# 9535             11 862      Unknown              51 010         Unknown
# 9536              9 946      Unknown              19 894         Unknown
# 9537          3 076 664    Very poor           4 091 963       Very poor
# 9538            163 932         Good             216 392  Unsatisfactory
# 9539          1 331 630      Unknown           1 717 804            Poor
#
#      Facebook_likes Twitter_mentions Google_pluses LinkedIn_mentions  \
# 0                 9                1            37                 7
# 1             94.2K            11.2K         11.7M             1.67K
# 2             13.5K            16.5K         19.3M               60K
# 3             5.87M            64.4K          127K             6.23K
# 4             17.2K            1.11K          798K              7.5K
# ...             ...              ...           ...               ...
# 9535              -               15             3                 -
# 9536              3              256           214                 4
# 9537              -                -             -                 -
# 9538              1                -           158                 5
# 9539              -                -             4                 -
#
#      Pinterest_pins StumbleUpon_views Status Traffic_Rank  Reach_Day  \
# 0                 -                 7     ok          954   0.071616
# 1             10.8K              246K     ok            1  38.505600
# 2                47              329K     ok            2  42.604800
# 3             4.15K             23.1K     ok            3  21.436800
# 4               433             68.9K     ok            6   7.699200
# ...             ...               ...    ...          ...        ...
# 9535              -                 -     ok       77 934   0.000955
# 9536              -                 1     ok       58 327   0.000831
# 9537              -                 -     ok          519   0.184320
# 9538              -                 1     ok           37   0.008160
# 9539              -                 -     ok        1 098   0.114240
#
#       Month_Average_Daily_Reach  Daily_Pageviews  \
# 0                      0.067968         0.009888
# 1                     40.793280         6.465600
# 2                     40.567680         5.934720
# 3                     21.513600         2.046720
# 4                      7.924800         0.732096
# ...                         ...              ...
# 9535                   0.000936         0.000115
# 9536                   0.000955         0.000055
# 9537                   0.277440         0.005683
# 9538                   0.009408         0.000250
# 9539                   0.091776         0.003706
#
#       Month_Average_Daily_Pageviews  Daily_Pageviews_per_user  \
# 0                          0.009154                    5.3760
# 1                          7.564032                    6.5760
# 2                          5.045568                    5.2416
# 3                          2.016960                    3.5904
# 4                          0.703910                    3.5808
# ...                             ...                       ...
# 9535                       0.000105                    4.7750
# 9536                       0.000069                    2.8650
# 9537                       0.008980                    1.2480
# 9538                       0.000295                    1.2480
# 9539                       0.002770                    1.2192
#
#       Reach_Day_percentage  Month_Average_Daily_Reach_percentage  \
# 0                     -1.1                                   1.0
# 1                     -0.3                                  -1.1
# 2                      5.5                                   1.8
# 3                      0.0                                  -1.5
# 4                     -1.8                                  -0.8
# ...                    ...                                   ...
# 9535                 -16.5                                   5.7
# 9536                 -10.2                                 -19.3
# 9537                 -11.9                                  70.4
# 9538                  19.2                                  32.6
# 9539                  -3.5                                   3.8
#
#       Daily_Pageviews_percentage  Month_Average_Daily_Pageviews_percentage  \
# 0                           -5.1                                      12.5
# 1                            1.8                                      -6.3
# 2                            9.7                                       0.5
# 3                           -8.2                                      -2.2
# 4                           -4.9                                      -0.5
# ...                          ...                                       ...
# 9535                         9.6                                      23.9
# 9536                        66.8                                     -41.1
# 9537                       -12.4                                      70.1
# 9538                         1.0                                      19.2
# 9539                        -4.3                                       5.7
#
#       Daily_Pageviews_per_user_percentage       Location  \
# 0                                    -4.1  United States
# 1                                     2.1  United States
# 2                                     3.8  United States
# 3                                    -8.2        Ireland
# 4                                    -3.2  United States
# ...                                   ...            ...
# 9535                                 28.6  United States
# 9536                                 86.0  United States
# 9537                                 -0.7  United States
# 9538                                -17.0  United States
# 9539                                 -0.7  United States
#
#                      Hosted_by                     Subnetworks  \
# 0                  Google Inc.                  216.58.203.227
# 1                  Google Inc.                  216.58.194.100
# 2                  Google Inc.                   172.217.2.238
# 3                     Facebook                     31.13.73.36
# 4                  Yahoo! Inc.   98.139.180.149, 98.139.183.24
# ...                        ...                             ...
# 9535               Google Inc.                   172.217.9.179
# 9536          CloudFlare, Inc.  104.25.125.117, 104.25.126.117
# 9537            Webzilla, Inc.                             NaN
# 9538          CloudFlare, Inc.    104.20.224.31, 104.20.225.31
# 9539  Amazon Technologies Inc.     34.202.76.242, 52.4.230.116
#
#                                              Registrant  \
# 0                                                   NaN
# 1                               DNS Admin (Google Inc.)
# 2                               DNS Admin (Google Inc.)
# 3                 Domain Administrator (Facebook, Inc.)
# 4                    Domain Administrator (Yahoo! Inc.)
# ...                                                 ...
# 9535  Name withheld. This Registrant is using a priv...
# 9536       Registration Private (Domains By Proxy, LLC)
# 9537  WHOIS AGENT (WHOIS PRIVACY PROTECTION SERVICE,...
# 9538                                    Taiqi Ran (NTD)
# 9539                 Domain Admin (Whois Privacy Corp.)
#
#                             Registrar      country
# 0                                 NaN  Afghanistan
# 1                    MARKMONITOR INC.  Afghanistan
# 2                    MARKMONITOR INC.  Afghanistan
# 3                    MARKMONITOR INC.  Afghanistan
# 4                    MARKMONITOR INC.  Afghanistan
# ...                               ...          ...
# 9535                       Nominet UK     Zimbabwe
# 9536                 GODADDY.COM, LLC     Zimbabwe
# 9537                       ENOM, INC.     Zimbabwe
# 9538                   NAME.COM, INC.     Zimbabwe
# 9539  INTERNET DOMAIN SERVICE BS CORP     Zimbabwe
#
# [9540 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9540 entries, 0 to 9539
# Data columns (total 31 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Country_Rank                              9540 non-null   int64
#  1   Website                                   9540 non-null   object
#  2   Trustworthiness                           9540 non-null   object
#  3   Avg_Daily_Visitors                        9396 non-null   object
#  4   Child_Safety                              9540 non-null   object
#  5   Avg_Daily_Pageviews                       9396 non-null   object
#  6   Privacy                                   9540 non-null   object
#  7   Facebook_likes                            9540 non-null   object
#  8   Twitter_mentions                          9540 non-null   object
#  9   Google_pluses                             9540 non-null   object
#  10  LinkedIn_mentions                         9540 non-null   object
#  11  Pinterest_pins                            9540 non-null   object
#  12  StumbleUpon_views                         9540 non-null   object
#  13  Status                                    9540 non-null   object
#  14  Traffic_Rank                              9539 non-null   object
#  15  Reach_Day                                 9478 non-null   float64
#  16  Month_Average_Daily_Reach                 9495 non-null   float64
#  17  Daily_Pageviews                           9478 non-null   float64
#  18  Month_Average_Daily_Pageviews             9494 non-null   float64
#  19  Daily_Pageviews_per_user                  9478 non-null   float64
#  20  Reach_Day_percentage                      9463 non-null   float64
#  21  Month_Average_Daily_Reach_percentage      9458 non-null   float64
#  22  Daily_Pageviews_percentage                9463 non-null   float64
#  23  Month_Average_Daily_Pageviews_percentage  9459 non-null   float64
#  24  Daily_Pageviews_per_user_percentage       9103 non-null   float64
#  25  Location                                  9467 non-null   object
#  26  Hosted_by                                 9416 non-null   object
#  27  Subnetworks                               9270 non-null   object
#  28  Registrant                                8540 non-null   object
#  29  Registrar                                 8579 non-null   object
#  30  country                                   9540 non-null   object
# dtypes: float64(10), int64(1), object(20)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#    Country_Rank            Website Trustworthiness Avg_Daily_Visitors  \
# 0             1  www.google.com.af       Excellent                NaN
# 1             2     www.google.com       Excellent        515 007 350
# 2             3    www.youtube.com       Excellent        506 457 282
# 3             4   www.facebook.com       Excellent        270 071 255
# 4             5      www.yahoo.com       Excellent         99 572 035
#
#   Child_Safety Avg_Daily_Pageviews    Privacy Facebook_likes Twitter_mentions  \
# 0    Excellent                 NaN  Excellent              9                1
# 1    Excellent       4 192 159 833  Excellent          94.2K            11.2K
# 2    Excellent       2 679 159 025  Excellent          13.5K            16.5K
# 3         Good       1 082 985 733  Excellent          5.87M            64.4K
# 4    Excellent         383 352 336  Excellent          17.2K            1.11K
#
#   Google_pluses LinkedIn_mentions Pinterest_pins StumbleUpon_views Status  \
# 0            37                 7              -                 7     ok
# 1         11.7M             1.67K          10.8K              246K     ok
# 2         19.3M               60K             47              329K     ok
# 3          127K             6.23K          4.15K             23.1K     ok
# 4          798K              7.5K            433             68.9K     ok
#
#   Traffic_Rank  Reach_Day  Month_Average_Daily_Reach  Daily_Pageviews  \
# 0          954   0.071616                   0.067968         0.009888
# 1            1  38.505600                  40.793280         6.465600
# 2            2  42.604800                  40.567680         5.934720
# 3            3  21.436800                  21.513600         2.046720
# 4            6   7.699200                   7.924800         0.732096
#
#    Month_Average_Daily_Pageviews  Daily_Pageviews_per_user  \
# 0                       0.009154                    5.3760
# 1                       7.564032                    6.5760
# 2                       5.045568                    5.2416
# 3                       2.016960                    3.5904
# 4                       0.703910                    3.5808
#
#    Reach_Day_percentage  Month_Average_Daily_Reach_percentage  \
# 0                  -1.1                                   1.0
# 1                  -0.3                                  -1.1
# 2                   5.5                                   1.8
# 3                   0.0                                  -1.5
# 4                  -1.8                                  -0.8
#
#    Daily_Pageviews_percentage  Month_Average_Daily_Pageviews_percentage  \
# 0                        -5.1                                      12.5
# 1                         1.8                                      -6.3
# 2                         9.7                                       0.5
# 3                        -8.2                                      -2.2
# 4                        -4.9                                      -0.5
#
#    Daily_Pageviews_per_user_percentage       Location    Hosted_by  \
# 0                                 -4.1  United States  Google Inc.
# 1                                  2.1  United States  Google Inc.
# 2                                  3.8  United States  Google Inc.
# 3                                 -8.2        Ireland     Facebook
# 4                                 -3.2  United States  Yahoo! Inc.
#
#                      Subnetworks                             Registrant  \
# 0                 216.58.203.227                                    NaN
# 1                 216.58.194.100                DNS Admin (Google Inc.)
# 2                  172.217.2.238                DNS Admin (Google Inc.)
# 3                    31.13.73.36  Domain Administrator (Facebook, Inc.)
# 4  98.139.180.149, 98.139.183.24     Domain Administrator (Yahoo! Inc.)
#
#           Registrar      country
# 0               NaN  Afghanistan
# 1  MARKMONITOR INC.  Afghanistan
# 2  MARKMONITOR INC.  Afghanistan
# 3  MARKMONITOR INC.  Afghanistan
# 4  MARKMONITOR INC.  Afghanistan

# %% [markdown]
# # should be numeric
# - Avg_Daily_Visitors
# - Avg_Daily_Pageviews
# - Facebook_likes
# - Google_pluses
# - Twitter_mentions
# - Google_pluses
# - LinkedIn_mentions
# - Pinterest_pins
# - StumbleUpon_views
# - Traffic_Rank

# %%
def clean_visitors(data):
    if data:
        if isinstance(data, str):
            data = data.replace(' ','')
            return float(data)
        return data
    return np.nan

df['Avg_Daily_Visitors'] = df['Avg_Daily_Visitors'].apply(clean_visitors)
df['Avg_Daily_Pageviews'] = df['Avg_Daily_Pageviews'].apply(clean_visitors)

# %%
df
# Out:
#       Country_Rank                    Website Trustworthiness  \
# 0                1          www.google.com.af       Excellent
# 1                2             www.google.com       Excellent
# 2                3            www.youtube.com       Excellent
# 3                4           www.facebook.com       Excellent
# 4                5              www.yahoo.com       Excellent
# ...            ...                        ...             ...
# 9535            46  www.newsdzezimbabwe.co.uk         Unknown
# 9536            47       www.nehandaradio.com         Unknown
# 9537            48         www.mysagagame.com       Very poor
# 9538            49                 www.ntd.tv  Unsatisfactory
# 9539            50  www.emailaccessonline.com            Poor
#
#       Avg_Daily_Visitors Child_Safety  Avg_Daily_Pageviews         Privacy  \
# 0                    NaN    Excellent                  NaN       Excellent
# 1            515007350.0    Excellent         4.192160e+09       Excellent
# 2            506457282.0    Excellent         2.679159e+09       Excellent
# 3            270071255.0         Good         1.082986e+09       Excellent
# 4             99572035.0    Excellent         3.833523e+08       Excellent
# ...                  ...          ...                  ...             ...
# 9535             11862.0      Unknown         5.101000e+04         Unknown
# 9536              9946.0      Unknown         1.989400e+04         Unknown
# 9537           3076664.0    Very poor         4.091963e+06       Very poor
# 9538            163932.0         Good         2.163920e+05  Unsatisfactory
# 9539           1331630.0      Unknown         1.717804e+06            Poor
#
#       Facebook_likes  Twitter_mentions  Google_pluses  LinkedIn_mentions  \
# 0                9.0               1.0           37.0                7.0
# 1          9420000.0         1120000.0      1170000.0           167000.0
# 2          1350000.0         1650000.0      1930000.0          6000000.0
# 3           587000.0         6440000.0     12700000.0           623000.0
# 4          1720000.0          111000.0     79800000.0           750000.0
# ...              ...               ...            ...                ...
# 9535             NaN              15.0            3.0                NaN
# 9536             3.0             256.0          214.0                4.0
# 9537             NaN               NaN            NaN                NaN
# 9538             1.0               NaN          158.0                5.0
# 9539             NaN               NaN            4.0                NaN
#
#       Pinterest_pins  StumbleUpon_views Status Traffic_Rank  Reach_Day  \
# 0                NaN                7.0     ok          954   0.071616
# 1          1080000.0         24600000.0     ok            1  38.505600
# 2               47.0         32900000.0     ok            2  42.604800
# 3           415000.0          2310000.0     ok            3  21.436800
# 4              433.0          6890000.0     ok            6   7.699200
# ...              ...                ...    ...          ...        ...
# 9535             NaN                NaN     ok       77 934   0.000955
# 9536             NaN                1.0     ok       58 327   0.000831
# 9537             NaN                NaN     ok          519   0.184320
# 9538             NaN                1.0     ok           37   0.008160
# 9539             NaN                NaN     ok        1 098   0.114240
#
#       Month_Average_Daily_Reach  Daily_Pageviews  \
# 0                      0.067968         0.009888
# 1                     40.793280         6.465600
# 2                     40.567680         5.934720
# 3                     21.513600         2.046720
# 4                      7.924800         0.732096
# ...                         ...              ...
# 9535                   0.000936         0.000115
# 9536                   0.000955         0.000055
# 9537                   0.277440         0.005683
# 9538                   0.009408         0.000250
# 9539                   0.091776         0.003706
#
#       Month_Average_Daily_Pageviews  Daily_Pageviews_per_user  \
# 0                          0.009154                    5.3760
# 1                          7.564032                    6.5760
# 2                          5.045568                    5.2416
# 3                          2.016960                    3.5904
# 4                          0.703910                    3.5808
# ...                             ...                       ...
# 9535                       0.000105                    4.7750
# 9536                       0.000069                    2.8650
# 9537                       0.008980                    1.2480
# 9538                       0.000295                    1.2480
# 9539                       0.002770                    1.2192
#
#       Reach_Day_percentage  Month_Average_Daily_Reach_percentage  \
# 0                     -1.1                                   1.0
# 1                     -0.3                                  -1.1
# 2                      5.5                                   1.8
# 3                      0.0                                  -1.5
# 4                     -1.8                                  -0.8
# ...                    ...                                   ...
# 9535                 -16.5                                   5.7
# 9536                 -10.2                                 -19.3
# 9537                 -11.9                                  70.4
# 9538                  19.2                                  32.6
# 9539                  -3.5                                   3.8
#
#       Daily_Pageviews_percentage  Month_Average_Daily_Pageviews_percentage  \
# 0                           -5.1                                      12.5
# 1                            1.8                                      -6.3
# 2                            9.7                                       0.5
# 3                           -8.2                                      -2.2
# 4                           -4.9                                      -0.5
# ...                          ...                                       ...
# 9535                         9.6                                      23.9
# 9536                        66.8                                     -41.1
# 9537                       -12.4                                      70.1
# 9538                         1.0                                      19.2
# 9539                        -4.3                                       5.7
#
#       Daily_Pageviews_per_user_percentage       Location  \
# 0                                    -4.1  United States
# 1                                     2.1  United States
# 2                                     3.8  United States
# 3                                    -8.2        Ireland
# 4                                    -3.2  United States
# ...                                   ...            ...
# 9535                                 28.6  United States
# 9536                                 86.0  United States
# 9537                                 -0.7  United States
# 9538                                -17.0  United States
# 9539                                 -0.7  United States
#
#                      Hosted_by                     Subnetworks  \
# 0                  Google Inc.                  216.58.203.227
# 1                  Google Inc.                  216.58.194.100
# 2                  Google Inc.                   172.217.2.238
# 3                     Facebook                     31.13.73.36
# 4                  Yahoo! Inc.   98.139.180.149, 98.139.183.24
# ...                        ...                             ...
# 9535               Google Inc.                   172.217.9.179
# 9536          CloudFlare, Inc.  104.25.125.117, 104.25.126.117
# 9537            Webzilla, Inc.                             NaN
# 9538          CloudFlare, Inc.    104.20.224.31, 104.20.225.31
# 9539  Amazon Technologies Inc.     34.202.76.242, 52.4.230.116
#
#                                              Registrant  \
# 0                                                   NaN
# 1                               DNS Admin (Google Inc.)
# 2                               DNS Admin (Google Inc.)
# 3                 Domain Administrator (Facebook, Inc.)
# 4                    Domain Administrator (Yahoo! Inc.)
# ...                                                 ...
# 9535  Name withheld. This Registrant is using a priv...
# 9536       Registration Private (Domains By Proxy, LLC)
# 9537  WHOIS AGENT (WHOIS PRIVACY PROTECTION SERVICE,...
# 9538                                    Taiqi Ran (NTD)
# 9539                 Domain Admin (Whois Privacy Corp.)
#
#                             Registrar      country
# 0                                 NaN  Afghanistan
# 1                    MARKMONITOR INC.  Afghanistan
# 2                    MARKMONITOR INC.  Afghanistan
# 3                    MARKMONITOR INC.  Afghanistan
# 4                    MARKMONITOR INC.  Afghanistan
# ...                               ...          ...
# 9535                       Nominet UK     Zimbabwe
# 9536                 GODADDY.COM, LLC     Zimbabwe
# 9537                       ENOM, INC.     Zimbabwe
# 9538                   NAME.COM, INC.     Zimbabwe
# 9539  INTERNET DOMAIN SERVICE BS CORP     Zimbabwe
#
# [9540 rows x 31 columns]

# %%
def number_converter(data):
    if isinstance(data, float):
        return data
    elif data:
        if '-' in data:
            return np.nan
        elif isinstance(data, str):
            data = data.replace(' ','')
            if data.strip().isnumeric():
                return int(data.strip())
            elif 'M' in data:
                data = float(data.replace("M",""))* 100000 
                return data
            elif 'K' in data:
                data = float(data.replace("K",""))* 100000
                return data
        else:
            return float(data)
df['Facebook_likes'] = df['Facebook_likes'].apply(number_converter)
df['Twitter_mentions'] = df['Twitter_mentions'].apply(number_converter)
df['Google_pluses'] = df['Google_pluses'].apply(number_converter)
df['LinkedIn_mentions'] = df['LinkedIn_mentions'].apply(number_converter)
df['Pinterest_pins'] = df['Pinterest_pins'].apply(number_converter)
df['StumbleUpon_views'] = df['StumbleUpon_views'].apply(number_converter)
df['Traffic_Rank'] = df['Traffic_Rank'].apply(number_converter)

# %%
df
# Out:
#       Country_Rank                    Website Trustworthiness  \
# 0                1          www.google.com.af       Excellent
# 1                2             www.google.com       Excellent
# 2                3            www.youtube.com       Excellent
# 3                4           www.facebook.com       Excellent
# 4                5              www.yahoo.com       Excellent
# ...            ...                        ...             ...
# 9535            46  www.newsdzezimbabwe.co.uk         Unknown
# 9536            47       www.nehandaradio.com         Unknown
# 9537            48         www.mysagagame.com       Very poor
# 9538            49                 www.ntd.tv  Unsatisfactory
# 9539            50  www.emailaccessonline.com            Poor
#
#       Avg_Daily_Visitors Child_Safety  Avg_Daily_Pageviews         Privacy  \
# 0                    NaN    Excellent                  NaN       Excellent
# 1            515007350.0    Excellent         4.192160e+09       Excellent
# 2            506457282.0    Excellent         2.679159e+09       Excellent
# 3            270071255.0         Good         1.082986e+09       Excellent
# 4             99572035.0    Excellent         3.833523e+08       Excellent
# ...                  ...          ...                  ...             ...
# 9535             11862.0      Unknown         5.101000e+04         Unknown
# 9536              9946.0      Unknown         1.989400e+04         Unknown
# 9537           3076664.0    Very poor         4.091963e+06       Very poor
# 9538            163932.0         Good         2.163920e+05  Unsatisfactory
# 9539           1331630.0      Unknown         1.717804e+06            Poor
#
#       Facebook_likes  Twitter_mentions  Google_pluses  LinkedIn_mentions  \
# 0                9.0               1.0           37.0                7.0
# 1          9420000.0         1120000.0      1170000.0           167000.0
# 2          1350000.0         1650000.0      1930000.0          6000000.0
# 3           587000.0         6440000.0     12700000.0           623000.0
# 4          1720000.0          111000.0     79800000.0           750000.0
# ...              ...               ...            ...                ...
# 9535             NaN              15.0            3.0                NaN
# 9536             3.0             256.0          214.0                4.0
# 9537             NaN               NaN            NaN                NaN
# 9538             1.0               NaN          158.0                5.0
# 9539             NaN               NaN            4.0                NaN
#
#       Pinterest_pins  StumbleUpon_views Status  Traffic_Rank  Reach_Day  \
# 0                NaN                7.0     ok         954.0   0.071616
# 1          1080000.0         24600000.0     ok           1.0  38.505600
# 2               47.0         32900000.0     ok           2.0  42.604800
# 3           415000.0          2310000.0     ok           3.0  21.436800
# 4              433.0          6890000.0     ok           6.0   7.699200
# ...              ...                ...    ...           ...        ...
# 9535             NaN                NaN     ok       77934.0   0.000955
# 9536             NaN                1.0     ok       58327.0   0.000831
# 9537             NaN                NaN     ok         519.0   0.184320
# 9538             NaN                1.0     ok          37.0   0.008160
# 9539             NaN                NaN     ok        1098.0   0.114240
#
#       Month_Average_Daily_Reach  Daily_Pageviews  \
# 0                      0.067968         0.009888
# 1                     40.793280         6.465600
# 2                     40.567680         5.934720
# 3                     21.513600         2.046720
# 4                      7.924800         0.732096
# ...                         ...              ...
# 9535                   0.000936         0.000115
# 9536                   0.000955         0.000055
# 9537                   0.277440         0.005683
# 9538                   0.009408         0.000250
# 9539                   0.091776         0.003706
#
#       Month_Average_Daily_Pageviews  Daily_Pageviews_per_user  \
# 0                          0.009154                    5.3760
# 1                          7.564032                    6.5760
# 2                          5.045568                    5.2416
# 3                          2.016960                    3.5904
# 4                          0.703910                    3.5808
# ...                             ...                       ...
# 9535                       0.000105                    4.7750
# 9536                       0.000069                    2.8650
# 9537                       0.008980                    1.2480
# 9538                       0.000295                    1.2480
# 9539                       0.002770                    1.2192
#
#       Reach_Day_percentage  Month_Average_Daily_Reach_percentage  \
# 0                     -1.1                                   1.0
# 1                     -0.3                                  -1.1
# 2                      5.5                                   1.8
# 3                      0.0                                  -1.5
# 4                     -1.8                                  -0.8
# ...                    ...                                   ...
# 9535                 -16.5                                   5.7
# 9536                 -10.2                                 -19.3
# 9537                 -11.9                                  70.4
# 9538                  19.2                                  32.6
# 9539                  -3.5                                   3.8
#
#       Daily_Pageviews_percentage  Month_Average_Daily_Pageviews_percentage  \
# 0                           -5.1                                      12.5
# 1                            1.8                                      -6.3
# 2                            9.7                                       0.5
# 3                           -8.2                                      -2.2
# 4                           -4.9                                      -0.5
# ...                          ...                                       ...
# 9535                         9.6                                      23.9
# 9536                        66.8                                     -41.1
# 9537                       -12.4                                      70.1
# 9538                         1.0                                      19.2
# 9539                        -4.3                                       5.7
#
#       Daily_Pageviews_per_user_percentage       Location  \
# 0                                    -4.1  United States
# 1                                     2.1  United States
# 2                                     3.8  United States
# 3                                    -8.2        Ireland
# 4                                    -3.2  United States
# ...                                   ...            ...
# 9535                                 28.6  United States
# 9536                                 86.0  United States
# 9537                                 -0.7  United States
# 9538                                -17.0  United States
# 9539                                 -0.7  United States
#
#                      Hosted_by                     Subnetworks  \
# 0                  Google Inc.                  216.58.203.227
# 1                  Google Inc.                  216.58.194.100
# 2                  Google Inc.                   172.217.2.238
# 3                     Facebook                     31.13.73.36
# 4                  Yahoo! Inc.   98.139.180.149, 98.139.183.24
# ...                        ...                             ...
# 9535               Google Inc.                   172.217.9.179
# 9536          CloudFlare, Inc.  104.25.125.117, 104.25.126.117
# 9537            Webzilla, Inc.                             NaN
# 9538          CloudFlare, Inc.    104.20.224.31, 104.20.225.31
# 9539  Amazon Technologies Inc.     34.202.76.242, 52.4.230.116
#
#                                              Registrant  \
# 0                                                   NaN
# 1                               DNS Admin (Google Inc.)
# 2                               DNS Admin (Google Inc.)
# 3                 Domain Administrator (Facebook, Inc.)
# 4                    Domain Administrator (Yahoo! Inc.)
# ...                                                 ...
# 9535  Name withheld. This Registrant is using a priv...
# 9536       Registration Private (Domains By Proxy, LLC)
# 9537  WHOIS AGENT (WHOIS PRIVACY PROTECTION SERVICE,...
# 9538                                    Taiqi Ran (NTD)
# 9539                 Domain Admin (Whois Privacy Corp.)
#
#                             Registrar      country
# 0                                 NaN  Afghanistan
# 1                    MARKMONITOR INC.  Afghanistan
# 2                    MARKMONITOR INC.  Afghanistan
# 3                    MARKMONITOR INC.  Afghanistan
# 4                    MARKMONITOR INC.  Afghanistan
# ...                               ...          ...
# 9535                       Nominet UK     Zimbabwe
# 9536                 GODADDY.COM, LLC     Zimbabwe
# 9537                       ENOM, INC.     Zimbabwe
# 9538                   NAME.COM, INC.     Zimbabwe
# 9539  INTERNET DOMAIN SERVICE BS CORP     Zimbabwe
#
# [9540 rows x 31 columns]
